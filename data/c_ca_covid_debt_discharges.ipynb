# %%
# !java -version
# Out:
# openjdk version "22.0.1" 2024-04-16
# OpenJDK Runtime Environment (build 22.0.1+8-16)
# OpenJDK 64-Bit Server VM (build 22.0.1+8-16, mixed mode, sharing)

# %% [markdown]
# ### This downloads and adds OpenJDK Java stuff to Java directory

# %%
# !curl "https://download.java.net/java/GA/jdk22.0.1/c7ec1332f7bb44aeba2eb341ae18aca4/8/GPL/openjdk-22.0.1_macos-x64_bin.tar.gz" | tar zxf -

# %% [markdown]
# ### This is where you should put it

# %%
# !mv jdk-22.0.1.jdk /Library/Java/JavaVirtualMachines/

# %%
# !pip install -q tabula-py

# %%
# !pip install jpype1
# Out:
# Collecting jpype1
#   Downloading jpype1-1.6.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (5.0 kB)
# Requirement already satisfied: packaging in /Users/Charlie/opt/anaconda3/envs/newpython/lib/python3.11/site-packages (from jpype1) (25.0)
# Downloading jpype1-1.6.0-cp311-cp311-macosx_10_9_universal2.whl (583 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 583.5/583.5 kB 8.2 MB/s  0:00:00
# Installing collected packages: jpype1
# Successfully installed jpype1-1.6.0

# %%
import tabula
import pandas as pd

# %% [markdown]
# ### This tells your Python profile where to find the Java JDK contents

# %%
# !echo export "JAVA_HOME=/Library/Java/JavaVirtualMachines/jdk-22.0.1.jdk/Contents/Home" >> ~/.zshrc

# %%
pdf_path = "2024-covid-19-block-grant-reports-7-26-24-a11y.pdf"

# %%
df_block = tabula.read_pdf(pdf_path, multiple_tables=False, pages="27-47", pandas_options={'header': None})
df_block = pd.concat(df_block, axis=1, ignore_index=True)
# Optional cleanup
df_block = df_block.reset_index(drop=True)

# %%
# --- Step 1: Extract all tables ---
dfs = tabula.read_pdf(
    pdf_path,
    pages="27-47",
    multiple_tables=True,
    pandas_options={'header': 0, 'dtype': str}
)

# Flatten if multiple_tables=True returns nested lists
dfs_flat = []
for item in dfs:
    if isinstance(item, list):
        dfs_flat.extend(item)
    else:
        dfs_flat.append(item)

# Drop empties
dfs_flat = [df for df in dfs_flat if df is not None and not df.empty]

# --- Step 2: Promote first row as header if not already ---
cleaned = []
for df in dfs_flat:
    if df.columns[0] == 0 or df.columns.dtype != object:
        # Sometimes header wasn't picked up correctly
        df.columns = df.iloc[0]
        df = df.iloc[1:].reset_index(drop=True)
    cleaned.append(df)

# --- Step 3: Group by header signature ---
# Define a signature for each table’s header to detect sameness
def header_signature(df):
    return tuple(str(c).strip().lower() for c in df.columns)

grouped = []
current_group = [cleaned[0]]
current_sig = header_signature(cleaned[0])

for df in cleaned[1:]:
    sig = header_signature(df)
    if sig == current_sig:
        # same header → stack vertically
        current_group.append(df)
    else:
        # new header → finish previous vertical stack
        grouped.append(pd.concat(current_group, ignore_index=True))
        current_group = [df]
        current_sig = sig

# append the final group
grouped.append(pd.concat(current_group, ignore_index=True))

# --- Step 4: Concatenate horizontally (side by side) across header groups ---
final_df = pd.concat(grouped, axis=1)

# optional cleanup
final_df = final_df.reset_index(drop=True)

# %%
final_df.columns.values[0] = "block_use"

# %%
final_df = final_df.drop(columns=["Category", "Subcategory", "..."], errors="ignore")

# %%
df = final_df[final_df['block_use'].str.contains('Discharging unpaid fees|Total Expended|Total Expenditures and Encumbrance', case=False, na=False)]

# %%
# Step 1: Set the first column as the new header row
df_t = df.set_index(df.columns[0]).T

# Step 2: Reset the index to turn old column headers into a column
df_t = df_t.reset_index().rename(columns={'index': 'district'})

df_t = df.set_index('block_use').T.reset_index().rename(columns={'index':'district'})

df_t
# Out:
# block_use             district Discharging unpaid fees Total Expended  \
# 0              Statewide Total             $20,199,178   $207,812,480
# 1          Allan Hancock Joint                       -        279,267
# 2              Antelope Valley               2,331,678      2,667,197
# 3                      Barstow                 250,969      1,452,472
# 4                  Butte-Glenn                       -      6,444,216
# ..                         ...                     ...            ...
# 82                  West Hills                       -        785,296
# 83                   West Kern                       -        731,095
# 84         West Valley-Mission               1,967,208      3,011,994
# 85                    Yosemite                       -      1,411,114
# 86                        Yuba                       -        431,720
#
# block_use Total Expenditures and Encumbrances
# 0                                $403,306,926
# 1                                   5,151,904
# 2                                   5,825,633
# 3                                   1,518,489
# 4                                   6,857,648
# ..                                        ...
# 82                                  1,589,297
# 83                                    731,095
# 84                                  6,802,861
# 85                                  9,554,739
# 86                                    431,720
#
# [87 rows x 4 columns]

# %%
df.to_csv(
    "block_grant_fee_discharges.csv", index=False)

# %%
df
# Out:
#                    district           col_1  \
# 0   Discharging unpaid fees  Total Expended
# 1               $20,199,178    $207,812,480
# 2                         -         279,267
# 3                 2,331,678       2,667,197
# 4                   250,969       1,452,472
# ..                      ...             ...
# 83                        -         785,296
# 84                        -         731,095
# 85                1,967,208       3,011,994
# 86                        -       1,411,114
# 87                        -         431,720
#
#                                   col_2
# 0   Total Expenditures and Encumbrances
# 1                          $403,306,926
# 2                             5,151,904
# 3                             5,825,633
# 4                             1,518,489
# ..                                  ...
# 83                            1,589,297
# 84                              731,095
# 85                            6,802,861
# 86                            9,554,739
# 87                              431,720
#
# [88 rows x 3 columns]

# %%
df.to_csv(
    "d_ftb_offset_2023.csv", index=False)

# %%
[j for i in range(7, df.shape[1], 6) for j in (i, i+1) if j < df.shape[1]]
# Out:
# [7, 8, 13, 14, 19, 20, 25, 26, 31, 32, 37, 38, 43, 44, 49, 50, 55, 56]

# %%
df = final_df.drop(final_df.columns[[i for i in range(7, final_df.shape[1], 6) for i in (i, i+1) if i < final_df.shape[1]]], axis=1)

# %%
def drop_col_pattern(df, start=7, step=6):
    """
    Drop the 8th & 9th columns (0-based 7,8), then every 6th & 7th after.
    Works regardless of column labels (uses .iloc positions only).
    """
    drop_pos = []
    i = start
    while i < final_df.shape[1]:
        drop_pos.extend([i, i + 1])
        i += step
    drop_pos = [p for p in drop_pos if p < final_df.shape[1]]

    # Keep all columns NOT in drop_pos, by position
    keep_pos = [i for i in range(df.shape[1]) if i not in drop_pos]
    return final_df.iloc[:, keep_pos].copy()

# Usage
df = drop_col_pattern(final_df)  # start=7 (8th col), step=6 by default
df
# Out:
#                                              Category  \
# 0                                         Basic Needs
# 1                                         Basic Needs
# 2                 Direct Emergency Grants to Students
# 3                 Direct Emergency Grants to Students
# 4                             Discharging unpaid fees
# 5                        Facilitate Distance Learning
# 6             Investments to Close the Digital Divide
# 7             Investments to Close the Digital Divide
# 8             Investments to Close the Digital Divide
# 9                  Mental Health Services and Support
# 10                Personal Protective Equipment (PPE)
# 11                Personal Protective Equipment (PPE)
# 12  Professional Development Opportunities for Fac...
# 13  Professional Development Opportunities for Fac...
# 14  Professional Development Opportunities for Fac...
# 15  Professional Development Opportunities for Fac...
# 16  Professional Development Opportunities for Fac...
# 17                            Reengagement Strategies
# 18                            Reengagement Strategies
# 19                            Reengagement Strategies
# 20                      Spending Flexibility Purposes
# 21                      Spending Flexibility Purposes
# 22                                   Student Services
# 23                                   Student Services
# 24                             Items Not Listed Above
# 25                                     Total Expended
# 26                                   Total Encumbered
# 27                Total Expenditures and Encumbrances
# 28                                  Remaining Unspent
#
#                                           Subcategory Statewide Total  \
# 0                                       Food Programs      $7,295,657
# 1                                     Housing Support        $869,834
# 2                                Financial Aid Grants     $12,519,484
# 3                                      Learning Tools        $402,918
# 4   Unpaid fees due or owed by student to communit...     $20,199,178
# 5   Grants to faculty to develop online, accelerat...        $367,138
# 6               Information Technology Infrastructure     $15,580,300
# 7             Facilitate Student Access to Technology      $8,203,244
# 8   Software and Hardware purchases that enable em...      $6,902,336
# 9                  Mental Health Services and Support      $1,976,789
# 10                                  Cleaning Supplies        $858,219
# 11                      Personal Protective Equipment      $2,753,718
# 12   Faculty Online Learning Professional Development      $1,167,314
# 13                      Student Reengagement Training        $359,162
# 14                Investments to Close Digital Divide         $84,906
# 15   Other Activities to Facilitate Distance Learning      $1,641,465
# 16  Professional development focused on culturally...      $1,038,942
# 17  Students with incomplete or failed Spring 2022...        $864,513
# 18  Students in high school or local communities t...      $5,266,033
# 19                             Outreach and Marketing      $9,448,402
# 20                           Retention and Enrollment      $5,165,612
# 21           Physical Plant and Instructional Support     $62,416,295
# 22  Increase academic support services – extended ...      $7,310,429
# 23  Assistance in applying for financial aid, Cali...        $476,494
# 24                                                  -     $34,644,097
# 25                                                  -    $207,812,480
# 26                                                  -    $195,494,445
# 27                                                  -    $403,306,926
# 28                                                  -    $246,693,074
#
#    Allan Hancock Joint Antelope Valley    Barstow Butte-Glenn   Cabrillo  \
# 0               30,583               -          -           -    117,760
# 1                    -               -          -           -          -
# 2                    -               -          -           -    396,254
# 3                    -               -          -           -          -
# 4                    -       2,331,678    250,969           -  1,394,784
# 5                    -               -          -           -      9,403
# 6                    -         146,823     39,562           -          -
# 7                    -               -    198,428      39,508     63,171
# 8                    -               -     58,562       8,294     29,616
# 9                    -               -     11,047      18,129          -
# 10                   -           1,818          -           -     21,061
# 11                   -               -          -           -     18,645
# 12                   -               -          -           -     33,980
# 13                   -               -          -           -     77,452
# 14                   -               -          -           -          -
# 15             171,067               -          -           -     23,312
# 16              22,667               -          -           -     22,746
# 17                   -               -          -           -      9,334
# 18                   -               -          -           -     32,134
# 19                   -         171,178          -           -          -
# 20                   -               -    176,693           -          -
# 21                   -               -    717,212   5,930,000    123,900
# 22                   -               -          -           -          -
# 23                   -               -          -           -          -
# 24              54,950          15,700          -     448,285    541,163
# 25             279,267       2,667,197  1,452,472   6,444,216  2,914,715
# 26           4,872,637       3,158,437     66,017     413,432  4,052,236
# 27           5,151,904       5,825,633  1,518,489   6,857,648  6,966,951
# 28                   -          36,285          -     521,713          -
#
#    Calbright   Cerritos  ... Solano County Sonoma\rCounty  \
# 0          -          -  ...             -              -
# 1          -          -  ...             -              -
# 2          -          -  ...             -              -
# 3          -          -  ...             -              -
# 4          -          -  ...       850,000      2,938,980
# 5          -          -  ...             -              -
# 6          -          -  ...             -              -
# 7          -          -  ...             -              -
# 8          -          -  ...     3,668,244      3,272,748
# 9          -    130,931  ...             -      9,750,332
# 10         -          -  ...     3,668,244     13,023,080
# 11         -          -  ...       240,580        605,848
# 12         -          -  ...           NaN            NaN
# 13         -          -  ...           NaN            NaN
# 14         -          -  ...           NaN            NaN
# 15         -          -  ...           NaN            NaN
# 16         -          -  ...           NaN            NaN
# 17         -          -  ...           NaN            NaN
# 18         -     35,025  ...           NaN            NaN
# 19         -     93,000  ...           NaN            NaN
# 20         -          -  ...           NaN            NaN
# 21         -          -  ...           NaN            NaN
# 22         -          -  ...           NaN            NaN
# 23         -          -  ...           NaN            NaN
# 24         -          -  ...           NaN            NaN
# 25         -    258,956  ...           NaN            NaN
# 26         -  3,800,000  ...           NaN            NaN
# 27         -  4,058,956  ...           NaN            NaN
# 28         -  6,570,142  ...           NaN            NaN
#
#                                           Subcategory Southwestern  \
# 0                                       Food Programs            -
# 1                                     Housing Support            -
# 2                                Financial Aid Grants      477,568
# 3                                      Learning Tools            -
# 4   Unpaid fees due or owed by student to communit...            -
# 5   Grants to faculty to develop online, accelerat...            -
# 6               Information Technology Infrastructure      318,809
# 7             Facilitate Student Access to Technology            -
# 8   Software and Hardware purchases that enable em...            -
# 9                  Mental Health Services and Support            -
# 10                                  Cleaning Supplies            -
# 11                      Personal Protective Equipment            -
# 12   Faculty Online Learning Professional Development       21,499
# 13                      Student Reengagement Training            -
# 14                Investments to Close Digital Divide            -
# 15   Other Activities to Facilitate Distance Learning            -
# 16  Professional development focused on culturally...            -
# 17  Students with incomplete or failed Spring 2022...            -
# 18  Students in high school or local communities t...            -
# 19                             Outreach and Marketing    1,887,997
# 20                           Retention and Enrollment            -
# 21           Physical Plant and Instructional Support            -
# 22  Increase academic support services – extended ...       28,470
# 23  Assistance in applying for financial aid, Cali...            -
# 24                                                  -            -
# 25                                                  -    2,734,343
# 26                                                  -    6,122,720
# 27                                                  -    8,857,063
# 28                                                  -            -
#
#    State Center Ventura County  \
# 0        40,281         33,329
# 1       722,910              -
# 2             -          2,000
# 3             -              -
# 4           276              -
# 5             -         18,660
# 6        95,223        160,663
# 7       249,886        317,322
# 8        64,533         26,265
# 9        27,474         38,552
# 10            -              -
# 11          787         18,889
# 12            -              -
# 13       17,921              -
# 14            -              -
# 15            -        142,974
# 16            -         38,505
# 17       39,552         37,000
# 18      463,764        199,781
# 19      259,755         69,428
# 20            -        385,997
# 21      803,464        677,744
# 22      528,045        204,768
# 23        3,513          2,672
# 24      271,420        305,741
# 25    3,588,804      2,680,288
# 26      636,470        199,100
# 27    4,225,274      2,879,388
# 28   13,577,066     11,865,789
#
#                                              Category  \
# 0                                         Basic Needs
# 1                                         Basic Needs
# 2                 Direct Emergency Grants to Students
# 3                 Direct Emergency Grants to Students
# 4                             Discharging unpaid fees
# 5                        Facilitate Distance Learning
# 6             Investments to Close the Digital Divide
# 7             Investments to Close the Digital Divide
# 8             Investments to Close the Digital Divide
# 9                  Mental Health Services and Support
# 10                Personal Protective Equipment (PPE)
# 11                Personal Protective Equipment (PPE)
# 12  Professional Development Opportunities for Fac...
# 13  Professional Development Opportunities for Fac...
# 14  Professional Development Opportunities for Fac...
# 15  Professional Development Opportunities for Fac...
# 16  Professional Development Opportunities for Fac...
# 17                            Reengagement Strategies
# 18                            Reengagement Strategies
# 19                            Reengagement Strategies
# 20                      Spending Flexibility Purposes
# 21                      Spending Flexibility Purposes
# 22                                   Student Services
# 23                                   Student Services
# 24                             Items Not Listed Above
# 25                                     Total Expended
# 26                                   Total Encumbered
# 27                Total Expenditures and Encumbrances
# 28                                  Remaining Unspent
#
#                                           Subcategory West Kern  \
# 0                                       Food Programs         -
# 1                                     Housing Support         -
# 2                                Financial Aid Grants         -
# 3                                      Learning Tools         -
# 4   Unpaid fees due or owed by student to communit...         -
# 5   Grants to faculty to develop online, accelerat...         -
# 6               Information Technology Infrastructure   731,095
# 7             Facilitate Student Access to Technology         -
# 8   Software and Hardware purchases that enable em...         -
# 9                  Mental Health Services and Support         -
# 10                                  Cleaning Supplies         -
# 11                      Personal Protective Equipment         -
# 12   Faculty Online Learning Professional Development         -
# 13                      Student Reengagement Training         -
# 14                Investments to Close Digital Divide         -
# 15   Other Activities to Facilitate Distance Learning         -
# 16  Professional development focused on culturally...         -
# 17  Students with incomplete or failed Spring 2022...         -
# 18  Students in high school or local communities t...         -
# 19                             Outreach and Marketing         -
# 20                           Retention and Enrollment         -
# 21           Physical Plant and Instructional Support         -
# 22  Increase academic support services – extended ...         -
# 23  Assistance in applying for financial aid, Cali...         -
# 24                                                  -         -
# 25                                                  -   731,095
# 26                                                  -         -
# 27                                                  -   731,095
# 28                                                  -   552,384
#
#    West Valley-Mission
# 0               29,156
# 1                    -
# 2               46,000
# 3                    -
# 4            1,967,208
# 5                    -
# 6              127,578
# 7              203,832
# 8              205,657
# 9                    -
# 10              60,774
# 11                   -
# 12                   -
# 13                   -
# 14                   -
# 15                   -
# 16              60,180
# 17                   -
# 18                   -
# 19             135,707
# 20                   -
# 21                   -
# 22                   -
# 23                   -
# 24             175,902
# 25           3,011,994
# 26           3,790,867
# 27           6,802,861
# 28             102,064
#
# [29 rows x 79 columns]

# %%
# Build the column indices to drop
drop_indices = []
start = 7  # 8th column (0-based)
while start < df.shape[1]:
    drop_indices.extend([start, start + 1])
    start += 6  # move 6 columns forward from the first in each pair

# Drop those columns safely (ignore if out of range)
drop_indices = [i for i in drop_indices if i < df.shape[1]]

# Drop by index position
df = final_df.drop(final_df.columns[drop_indices], axis=1)

# %%
df
# Out:
#                                              Category  \
# 0                                         Basic Needs
# 1                                         Basic Needs
# 2                 Direct Emergency Grants to Students
# 3                 Direct Emergency Grants to Students
# 4                             Discharging unpaid fees
# 5                        Facilitate Distance Learning
# 6             Investments to Close the Digital Divide
# 7             Investments to Close the Digital Divide
# 8             Investments to Close the Digital Divide
# 9                  Mental Health Services and Support
# 10                Personal Protective Equipment (PPE)
# 11                Personal Protective Equipment (PPE)
# 12  Professional Development Opportunities for Fac...
# 13  Professional Development Opportunities for Fac...
# 14  Professional Development Opportunities for Fac...
# 15  Professional Development Opportunities for Fac...
# 16  Professional Development Opportunities for Fac...
# 17                            Reengagement Strategies
# 18                            Reengagement Strategies
# 19                            Reengagement Strategies
# 20                      Spending Flexibility Purposes
# 21                      Spending Flexibility Purposes
# 22                                   Student Services
# 23                                   Student Services
# 24                             Items Not Listed Above
# 25                                     Total Expended
# 26                                   Total Encumbered
# 27                Total Expenditures and Encumbrances
# 28                                  Remaining Unspent
#
#                                           Subcategory Statewide Total  \
# 0                                       Food Programs      $7,295,657
# 1                                     Housing Support        $869,834
# 2                                Financial Aid Grants     $12,519,484
# 3                                      Learning Tools        $402,918
# 4   Unpaid fees due or owed by student to communit...     $20,199,178
# 5   Grants to faculty to develop online, accelerat...        $367,138
# 6               Information Technology Infrastructure     $15,580,300
# 7             Facilitate Student Access to Technology      $8,203,244
# 8   Software and Hardware purchases that enable em...      $6,902,336
# 9                  Mental Health Services and Support      $1,976,789
# 10                                  Cleaning Supplies        $858,219
# 11                      Personal Protective Equipment      $2,753,718
# 12   Faculty Online Learning Professional Development      $1,167,314
# 13                      Student Reengagement Training        $359,162
# 14                Investments to Close Digital Divide         $84,906
# 15   Other Activities to Facilitate Distance Learning      $1,641,465
# 16  Professional development focused on culturally...      $1,038,942
# 17  Students with incomplete or failed Spring 2022...        $864,513
# 18  Students in high school or local communities t...      $5,266,033
# 19                             Outreach and Marketing      $9,448,402
# 20                           Retention and Enrollment      $5,165,612
# 21           Physical Plant and Instructional Support     $62,416,295
# 22  Increase academic support services – extended ...      $7,310,429
# 23  Assistance in applying for financial aid, Cali...        $476,494
# 24                                                  -     $34,644,097
# 25                                                  -    $207,812,480
# 26                                                  -    $195,494,445
# 27                                                  -    $403,306,926
# 28                                                  -    $246,693,074
#
#    Allan Hancock Joint Antelope Valley    Barstow Butte-Glenn  \
# 0               30,583               -          -           -
# 1                    -               -          -           -
# 2                    -               -          -           -
# 3                    -               -          -           -
# 4                    -       2,331,678    250,969           -
# 5                    -               -          -           -
# 6                    -         146,823     39,562           -
# 7                    -               -    198,428      39,508
# 8                    -               -     58,562       8,294
# 9                    -               -     11,047      18,129
# 10                   -           1,818          -           -
# 11                   -               -          -           -
# 12                   -               -          -           -
# 13                   -               -          -           -
# 14                   -               -          -           -
# 15             171,067               -          -           -
# 16              22,667               -          -           -
# 17                   -               -          -           -
# 18                   -               -          -           -
# 19                   -         171,178          -           -
# 20                   -               -    176,693           -
# 21                   -               -    717,212   5,930,000
# 22                   -               -          -           -
# 23                   -               -          -           -
# 24              54,950          15,700          -     448,285
# 25             279,267       2,667,197  1,452,472   6,444,216
# 26           4,872,637       3,158,437     66,017     413,432
# 27           5,151,904       5,825,633  1,518,489   6,857,648
# 28                   -          36,285          -     521,713
#
#                                              Category  \
# 0                                         Basic Needs
# 1                                         Basic Needs
# 2                 Direct Emergency Grants to Students
# 3                 Direct Emergency Grants to Students
# 4                             Discharging unpaid fees
# 5                        Facilitate Distance Learning
# 6             Investments to Close the Digital Divide
# 7             Investments to Close the Digital Divide
# 8             Investments to Close the Digital Divide
# 9                  Mental Health Services and Support
# 10                Personal Protective Equipment (PPE)
# 11                Personal Protective Equipment (PPE)
# 12  Professional Development Opportunities for Fac...
# 13  Professional Development Opportunities for Fac...
# 14  Professional Development Opportunities for Fac...
# 15  Professional Development Opportunities for Fac...
# 16  Professional Development Opportunities for Fac...
# 17                            Reengagement Strategies
# 18                            Reengagement Strategies
# 19                            Reengagement Strategies
# 20                      Spending Flexibility Purposes
# 21                      Spending Flexibility Purposes
# 22                                   Student Services
# 23                                   Student Services
# 24                             Items Not Listed Above
# 25                                     Total Expended
# 26                                   Total Encumbered
# 27                Total Expenditures and Encumbrances
# 28                                  Remaining Unspent
#
#                                           Subcategory   Cabrillo  ...  \
# 0                                       Food Programs    117,760  ...
# 1                                     Housing Support          -  ...
# 2                                Financial Aid Grants    396,254  ...
# 3                                      Learning Tools          -  ...
# 4   Unpaid fees due or owed by student to communit...  1,394,784  ...
# 5   Grants to faculty to develop online, accelerat...      9,403  ...
# 6               Information Technology Infrastructure          -  ...
# 7             Facilitate Student Access to Technology     63,171  ...
# 8   Software and Hardware purchases that enable em...     29,616  ...
# 9                  Mental Health Services and Support          -  ...
# 10                                  Cleaning Supplies     21,061  ...
# 11                      Personal Protective Equipment     18,645  ...
# 12   Faculty Online Learning Professional Development     33,980  ...
# 13                      Student Reengagement Training     77,452  ...
# 14                Investments to Close Digital Divide          -  ...
# 15   Other Activities to Facilitate Distance Learning     23,312  ...
# 16  Professional development focused on culturally...     22,746  ...
# 17  Students with incomplete or failed Spring 2022...      9,334  ...
# 18  Students in high school or local communities t...     32,134  ...
# 19                             Outreach and Marketing          -  ...
# 20                           Retention and Enrollment          -  ...
# 21           Physical Plant and Instructional Support    123,900  ...
# 22  Increase academic support services – extended ...          -  ...
# 23  Assistance in applying for financial aid, Cali...          -  ...
# 24                                                  -    541,163  ...
# 25                                                  -  2,914,715  ...
# 26                                                  -  4,052,236  ...
# 27                                                  -  6,966,951  ...
# 28                                                  -          -  ...
#
#    State Center Ventura County Victor Valley West Hills  \
# 0        40,281         33,329             -          -
# 1       722,910              -             -          -
# 2             -          2,000        24,376    372,137
# 3             -              -             -          -
# 4           276              -       161,292          -
# 5             -         18,660             -          -
# 6        95,223        160,663             -          -
# 7       249,886        317,322             -    351,212
# 8        64,533         26,265       332,343      7,320
# 9        27,474         38,552             -          -
# 10            -              -        45,790     37,704
# 11          787         18,889             -      4,665
# 12            -              -             -          -
# 13       17,921              -             -          -
# 14            -              -             -          -
# 15            -        142,974             -          -
# 16            -         38,505             -          -
# 17       39,552         37,000             -          -
# 18      463,764        199,781             -          -
# 19      259,755         69,428       330,919     12,049
# 20            -        385,997       660,439          -
# 21      803,464        677,744     1,332,011          -
# 22      528,045        204,768       150,000          -
# 23        3,513          2,672        20,000          -
# 24      271,420        305,741       166,119        209
# 25    3,588,804      2,680,288     3,223,289    785,296
# 26      636,470        199,100       776,962    804,001
# 27    4,225,274      2,879,388     4,000,251  1,589,297
# 28   13,577,066     11,865,789     1,818,011  1,670,651
#
#                                              Category  \
# 0                                         Basic Needs
# 1                                         Basic Needs
# 2                 Direct Emergency Grants to Students
# 3                 Direct Emergency Grants to Students
# 4                             Discharging unpaid fees
# 5                        Facilitate Distance Learning
# 6             Investments to Close the Digital Divide
# 7             Investments to Close the Digital Divide
# 8             Investments to Close the Digital Divide
# 9                  Mental Health Services and Support
# 10                Personal Protective Equipment (PPE)
# 11                Personal Protective Equipment (PPE)
# 12  Professional Development Opportunities for Fac...
# 13  Professional Development Opportunities for Fac...
# 14  Professional Development Opportunities for Fac...
# 15  Professional Development Opportunities for Fac...
# 16  Professional Development Opportunities for Fac...
# 17                            Reengagement Strategies
# 18                            Reengagement Strategies
# 19                            Reengagement Strategies
# 20                      Spending Flexibility Purposes
# 21                      Spending Flexibility Purposes
# 22                                   Student Services
# 23                                   Student Services
# 24                             Items Not Listed Above
# 25                                     Total Expended
# 26                                   Total Encumbered
# 27                Total Expenditures and Encumbrances
# 28                                  Remaining Unspent
#
#                                           Subcategory West Kern  \
# 0                                       Food Programs         -
# 1                                     Housing Support         -
# 2                                Financial Aid Grants         -
# 3                                      Learning Tools         -
# 4   Unpaid fees due or owed by student to communit...         -
# 5   Grants to faculty to develop online, accelerat...         -
# 6               Information Technology Infrastructure   731,095
# 7             Facilitate Student Access to Technology         -
# 8   Software and Hardware purchases that enable em...         -
# 9                  Mental Health Services and Support         -
# 10                                  Cleaning Supplies         -
# 11                      Personal Protective Equipment         -
# 12   Faculty Online Learning Professional Development         -
# 13                      Student Reengagement Training         -
# 14                Investments to Close Digital Divide         -
# 15   Other Activities to Facilitate Distance Learning         -
# 16  Professional development focused on culturally...         -
# 17  Students with incomplete or failed Spring 2022...         -
# 18  Students in high school or local communities t...         -
# 19                             Outreach and Marketing         -
# 20                           Retention and Enrollment         -
# 21           Physical Plant and Instructional Support         -
# 22  Increase academic support services – extended ...         -
# 23  Assistance in applying for financial aid, Cali...         -
# 24                                                  -         -
# 25                                                  -   731,095
# 26                                                  -         -
# 27                                                  -   731,095
# 28                                                  -   552,384
#
#    West Valley-Mission   Yosemite       Yuba
# 0               29,156     75,000          -
# 1                    -          -          -
# 2               46,000          -      1,362
# 3                    -          -          -
# 4            1,967,208          -          -
# 5                    -          -          -
# 6              127,578          -    312,825
# 7              203,832    301,619     63,931
# 8              205,657     63,486     47,766
# 9                    -     50,000          -
# 10              60,774          -          -
# 11                   -          -          -
# 12                   -          -          -
# 13                   -          -          -
# 14                   -          -          -
# 15                   -     33,529      5,836
# 16              60,180          -          -
# 17                   -          -          -
# 18                   -          -          -
# 19             135,707          -          -
# 20                   -    887,480          -
# 21                   -          -          -
# 22                   -          -          -
# 23                   -          -          -
# 24             175,902          -          -
# 25           3,011,994  1,411,114    431,720
# 26           3,790,867  8,143,625          -
# 27           6,802,861  9,554,739    431,720
# 28             102,064          -  3,972,418
#
# [29 rows x 117 columns]

# %%
df_block = pd.concat(df_block, ignore_index=True)
df_block = df_block.iloc[30:]
df_block = df_block.reset_index(drop=True)
df_block = df_block.drop(0)
df_block = df_block.drop(0, axis=1)

# %%
df_block
# Out:
#                                        0                     1  \
# 0                               Category           Subcategory
# 1                            Basic Needs         Food Programs
# 2                            Basic Needs       Housing Support
# 3    Direct Emergency Grants to Students  Financial Aid Grants
# 4    Direct Emergency Grants to Students        Learning Tools
# ..                                   ...                   ...
# 475                             Category           Subcategory
# 476                       Total Expended                     -
# 477                     Total Encumbered                     -
# 478  Total Expenditures and Encumbrances                     -
# 479                    Remaining Unspent                     -
#
#                    2                    3                4          5  \
# 0    Statewide Total  Allan Hancock Joint  Antelope Valley    Barstow
# 1         $7,295,657               30,583                -          -
# 2           $869,834                    -                -          -
# 3        $12,519,484                    -                -          -
# 4           $402,918                    -                -          -
# ..               ...                  ...              ...        ...
# 475        West Kern  West Valley-Mission         Yosemite       Yuba
# 476          731,095            3,011,994        1,411,114    431,720
# 477                -            3,790,867        8,143,625          -
# 478          731,095            6,802,861        9,554,739    431,720
# 479          552,384              102,064                -  3,972,418
#
#                6
# 0    Butte-Glenn
# 1              -
# 2              -
# 3              -
# 4              -
# ..           ...
# 475          NaN
# 476          NaN
# 477          NaN
# 478          NaN
# 479          NaN
#
# [480 rows x 7 columns]

# %%
df_block = df_block.rename(columns=
    {1: 'agencytype', 2:'name', 3:'pit_count', 4:'pit_amount',
     5:'lottery_count', 6:'lottery_amount', 7:'property_count',
     8:'property_amount', 9: 'all_count', 10: 'all_amount'})
df_2023

# %%
pdf_path = "2024-covid-19-block-grant-reports-7-26-24-a11y.pdf"

# %%
df_2023 = tabula.read_pdf(pdf_path, multiple_tables=False, pages='19-42', pandas_options={'header': None})
df_2023 = pd.concat(df_2023, ignore_index=True)
df_2023 = df_2023.iloc[30:]
df_2023 = df_2023.reset_index(drop=True)
df_2023 = df_2023.drop(0)
df_2023 = df_2023.drop(0, axis=1)
df_2023 = df_2023.rename(columns=
    {1: 'agencytype', 2:'name', 3:'pit_count', 4:'pit_amount',
     5:'lottery_count', 6:'lottery_amount', 7:'property_count',
     8:'property_amount', 9: 'all_count', 10: 'all_amount'})
df_2023
# Out:
#           agencytype                             name  pit_count  \
# 1                NaN                  CITY OF PARLIER         32
# 2                NaN                   CITY OF EXETER          7
# 3                NaN              CITY OF SHASTA LAKE          7
# 4                NaN             CITY OF GARDEN GROVE        761
# 5                NaN                  CITY OF REDDING          7
# ..               ...                              ...        ...
# 622              NaN  SUPERIOR COURT OF SAN FRANCISCO      1,844
# 623              NaN         SAN DIEGO SUPERIOR COURT      4,251
# 624  Z - OTHER Total                              NaN      6,712
# 625              NaN                              NaN    822,680
# 626              NaN                              NaN  3,058,682
#
#             pit_amount lottery_count  lottery_amount property_count  \
# 1            $6,152.00           NaN             NaN            NaN
# 2              $679.00           NaN             NaN            NaN
# 3              $721.00           NaN             NaN            NaN
# 4          $141,768.19             9       $2,386.14              8
# 5            $1,211.46           NaN             NaN            NaN
# ..                 ...           ...             ...            ...
# 622        $549,501.81            25      $10,923.75             54
# 623      $1,255,279.80            47      $20,325.07             90
# 624      $2,003,259.91            80      $37,284.57            162
# 625    $345,673,915.94         8,865   $7,198,070.02         24,302
# 626  $1,090,644,514.54        32,186  $25,533,001.25        105,498
#
#     property_amount  all_count         all_amount
# 1               NaN         32          $6,152.00
# 2               NaN          7            $679.00
# 3               NaN          7            $721.00
# 4           $520.70        778        $144,675.03
# 5               NaN          7          $1,211.46
# ..              ...        ...                ...
# 622       $7,347.93      1,923        $567,773.49
# 623      $16,820.02      4,388      $1,292,424.89
# 624      $27,917.47      6,954      $2,068,461.95
# 625   $7,267,478.12    855,847    $360,139,464.08
# 626  $29,342,756.71  3,196,366  $1,145,520,272.50
#
# [626 rows x 10 columns]

# %%
df_2023.to_csv(
    "d_ftb_offset_2023.csv", index=False)

# %%
dfconcat_cols1to3 = pd.concat(df_cols1to3)

dfconcat_cols1to3['row'] = dfconcat_cols1to3.reset_index().index

# %%
df_cols4to6 = tabula.read_pdf(pdf_path, multiple_tables=True, pages=[16,20,26,27],
    pandas_options={'header': None})

dfconcat_cols4to6 = pd.concat(df_cols4to6)

dfconcat_cols4to6['row'] = dfconcat_cols4to6.reset_index().index

# %%
df_cols7to9 = tabula.read_pdf(pdf_path, multiple_tables=True, pages=[17,21,28,29],
    pandas_options={'header': None})

dfconcat_cols7to9 = pd.concat(df_cols7to9)

dfconcat_cols7to9['row'] = dfconcat_cols7to9.reset_index().index

# %%
df_ftb_merge_cols1to3_7to9 = dfconcat_cols1to3.merge(dfconcat_cols7to9,on='row')

# %%
df_ftb_merge_cols1to3_7to9 = df_ftb_merge_cols1to3_7to9.rename(columns=
    {'0_x': 'agency', '1_x': 'pit_count', '2_x': 'pit_amount', 
     '1_y': 'all_count', '2_y': 'all_amount'})

# %%
df_ftb_merge_cols1to3_7to9.dropna(subset=['agency'], inplace=True)

# %%
df_ftb_merge_cols1to3_7to9 = df_ftb_merge_cols1to3_7to9.drop(columns=['row', '0_y'])

# %%
pd.set_option('display.max_rows', None)

# %%
df_ftb_merge_cols1to3_7to9
# Out:
#                                  agency pit_count     pit_amount all_count  \
# 0     CALF STATE POLYTECHNIC UNIVERSITY       534    $140,825.24       546
# 1      CALIFORNIA STATE UNIV NORTHRIDGE     1,056    $328,633.46     1,099
# 2          UNIVERSITY OF CALIFORNIA, OP     3,139  $1,401,548.97     3,218
# 3                        CSU SACRAMENTO       665    $176,150.92       685
# 4                                  UCLA       381     $50,701.63       388
# 5                      CSU, BAKERSFIELD       608    $167,703.71       630
# 6   UNIVERSITY OF CALIFORNIA, RIVERSIDE       674    $263,721.21       700
# 7                      UC SANTA BARBARA       299     $43,273.59       301
# 8                  CSU MARITIME ACADEMY        29     $21,760.83        31
# 9                          FRESNO STATE        75      $9,173.41        77
# 10      CALIF. STATE UNIV. MONTEREY BAY         2        $251.11         3
# 11  UCLA DEBT MANAGEMENT SERVICES (DMS)       694    $270,251.92       738
# 12                  CSU DOMINGUEZ HILLS        87     $10,313.19        89
# 13   UNIVERSITY OF CALIFORNIA, BERKELEY       200     $93,625.89       204
# 14                       CSU NORTHRIDGE       202     $26,224.47       209
# 15      UNIVERSITY OF CALIFORNIA, DAVIS       656    $188,773.41       668
# 18                         UMASS GLOBAL       711    $379,398.85       732
# 19               UNIVERSITY OF REDLANDS        66     $39,289.43        68
# 20       NOTRE DAME DE NAMUR UNIVERSITY        42     $14,806.76        43
# 21        UNIVERSITY OF SOUTHERN CALIF.       220    $112,150.82       235
# 22                PEPPERDINE UNIVERSITY        25     $23,058.06        25
# 23                  STANFORD UNIVERSITY        19     $13,659.39        19
# 24               SANTA CLARA UNIVERSITY        69      $8,703.57        69
# 25               UNIVERSITY OF LA VERNE       122     $43,587.36       124
# 26                     BIOLA UNIVERSITY         8      $2,264.33         8
# 27                     WHITTIER COLLEGE       104     $60,308.73       110
# 28                LOMA LINDA UNIVERSITY        35     $25,458.37        35
# 29          LOYOLA MARYMOUNT UNIVERSITY       272    $139,692.59       280
# 30           SAINT MARY'S COLLEGE OF CA        28     $12,825.79        29
# 31                 LA SIERRA UNIVERSITY        48     $15,481.51        48
# 32                   CA COLLEGE OF ARTS        13      $3,580.13        14
# 33                   CHAPMAN UNIVERSITY        43     $18,294.08        44
# 36                      CYPRESS COLLEGE       140     $11,446.54       141
# 37             SOLANO COMMUNITY COLLEGE        82      $9,063.94        84
# 38                      PALOMAR COLLEGE        57      $7,255.46        59
# 39       SAN FRANCISCO STATE UNIVERSITY        79      $8,521.70        79
# 40                PASEDENA CITY COLLEGE        57      $4,073.00        59
# 41                       CSU SACRAMENTO        67      $5,758.46        70
# 42               SAN JOSE EVERGREEN CCD        33      $3,005.08        33
# 43                        UC SANTA CRUZ        76      $8,417.29        77
# 44                      CHAFFEY COLLEGE        60      $5,232.00        63
# 45           LOS ANGELES VALLEY COLLEGE        59      $4,872.47        66
# 46                IRVINE VALLEY COLLEGE        63      $5,109.44        65
# 47     RIVERSIDE COMMUNITY COLLEGE DIST        94     $10,901.99        96
# 48                  GOLDEN WEST COLLEGE       108      $7,734.15       110
# 49                 ORANGE COAST COLLEGE        67      $4,227.50        71
# 50          COASTLINE COMMUNITY COLLEGE        10        $819.00        10
# 51              MARIN COMMUNITY COLLEGE        22      $3,753.34        22
# 52      NAPA VALLEY COLLEGE POLICE DEPT        27      $2,268.00        27
# 53                   CERRO COSO COLLEGE        10        $662.00        10
# 54                  BAKERSFIELD COLLEGE       177     $16,872.49       181
# 55                  PORTERVILLE COLLEGE        52      $2,969.00        52
# 56            SAN JOSE STATE UNIVERSITY       482    $159,078.42       501
# 57                      CSU, LONG BEACH       978    $297,701.39     1,016
# 58                     CSU, LOS ANGELES     1,200    $315,038.77     1,229
# 59           SAN DIEGO STATE UNIVERSITY       740    $202,194.88       749
# 60       CAL STATE UNIVERSITY, EAST BAY     1,158    $365,985.39     1,184
# 61   CALIFORNIA STATE UNIVERSITY,FRESNO       389    $100,781.16       391
# 62    CALIFORNIA STATE UNIVERSITY CHICO       427    $128,113.30       445
# 63                      CSU, STANISLAUS       373     $97,451.63       384
# 64          CALIFORNIA STATE UNIVERSITY     1,164    $405,009.41     1,202
# 65     CALIF STATE UNIV, SAN BERNARDINO        41     $20,777.41        43
# 66            HUMBOLDT STATE UNIVERSITY       381     $68,270.31       386
# 67          CALIFORNIA STATE UNIVERSITY     1,697    $351,371.94     1,763
# 68       SAN FRANCISCO STATE UNIVERSITY       999    $281,839.18     1,014
# 69              SONOMA STATE UNIVERSITY        27     $12,310.05        28
# 70                CA COMMUNITY COLLEGES    58,216  $8,618,243.85    59,363
# 71       CA STATE UNIVERSITY SAN MARCOS       381    $110,263.14       388
# 72                     CSU MONTEREY BAY       154     $48,490.86       162
# 73                   CSU SAN BERNARDINO       195     $19,202.90       204
# 74                  CSU CHANNEL ISLANDS       115     $23,061.70       116
# 75               MT SAN ANTONIO COLLEGE       254     $31,319.82       264
# 76   CALIF POLYTECHNIC STATE UNIVERSITY       111     $35,865.07       116
# 77     SAN MATEO COMMUNITY COLLEGE DIST       124     $18,343.57       130
#
#        all_amount
# 0     $143,027.04
# 1     $341,169.88
# 2   $1,412,893.93
# 3     $177,456.73
# 4      $51,390.12
# 5     $172,614.60
# 6     $269,411.04
# 7      $43,414.02
# 8      $22,182.28
# 9       $9,430.41
# 10        $347.78
# 11    $274,722.18
# 12     $10,984.19
# 13     $94,289.60
# 14     $26,757.28
# 15    $189,615.02
# 18    $381,144.10
# 19     $40,102.43
# 20     $14,833.13
# 21    $115,111.20
# 22     $23,058.06
# 23     $13,659.39
# 24      $8,703.57
# 25     $44,509.15
# 26      $2,264.33
# 27     $61,948.98
# 28     $25,458.37
# 29    $139,807.24
# 30     $13,825.79
# 31     $15,481.51
# 32      $3,774.25
# 33     $18,856.08
# 36     $11,447.54
# 37      $9,146.20
# 38      $7,449.46
# 39      $8,521.70
# 40      $4,123.35
# 41      $6,007.21
# 42      $3,005.08
# 43      $8,471.24
# 44      $5,339.76
# 45      $5,253.64
# 46      $5,235.03
# 47     $10,986.99
# 48      $8,036.15
# 49      $4,447.50
# 50        $819.00
# 51      $3,753.34
# 52      $2,268.00
# 53        $662.00
# 54     $17,149.68
# 55      $2,969.00
# 56    $162,646.41
# 57    $302,938.86
# 58    $319,558.61
# 59    $203,161.75
# 60    $371,658.32
# 61    $100,845.61
# 62    $132,201.20
# 63     $97,870.33
# 64    $417,671.78
# 65     $20,835.92
# 66     $68,512.43
# 67    $364,174.56
# 68    $284,313.52
# 69     $12,735.15
# 70  $8,751,968.62
# 71    $114,886.27
# 72     $50,099.86
# 73     $19,693.91
# 74     $23,230.10
# 75     $31,641.39
# 76     $36,228.75
# 77     $18,519.51

# %%
df_ftb_merge_cols1to3_7to9.to_csv(
    "d_ftb_offset_2019_pra.csv", index=False)
